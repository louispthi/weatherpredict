# %% [markdown]
# # Cleaning Datas for a linear regression model

# %% [markdown]
# We now prepare the datas specifically for our linear regression model. Our goal will be to predict the feature 'temp' on a given day using datas from the previous 3 days. We use the data set that we initially cleaned in cleaning_datas.ipynb

# %% [markdown]
# We import the libraries.

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %% [markdown]
# We put the csv file back into a dataframe. We put 'df_iso' into datetime format and setting as index.

# %%
df_lr = pd.read_csv('weather_data_initial_clean.csv')
df_lr['dt_iso'] = pd.to_datetime(df_lr['dt_iso'], format='%Y-%m-%d %H:%M:%S.%f')
df_lr = df_lr.set_index('dt_iso')
print('Data Shape = {}'.format(df_lr.shape))
print(df_lr.columns)
# Out:
# Data Shape = (364512, 13)
# Index(['temp', 'feels_like', 'pressure', 'humidity', 'wind_speed', 'wind_deg',
#        'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h', 'clouds_all', 'weather_id',
#        'weather_main'],
#       dtype='object')

# %%
df_lr.head()
# Out:
#                        temp  feels_like  pressure  humidity  wind_speed  \
# dt_iso
# 1979-01-01 00:00:00  275.12      269.76      1025        80         4.6
# 1979-01-01 01:00:00  275.08      271.53      1023        80         2.0
# 1979-01-01 02:00:00  275.06      271.16      1022        80         2.5
# 1979-01-01 03:00:00  275.97      267.30      1021        86         9.7
# 1979-01-01 04:00:00  276.32      267.88      1019        93         9.7
#
#                      wind_deg  rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  \
# dt_iso
# 1979-01-01 00:00:00       140      NaN      NaN      NaN      NaN          90
# 1979-01-01 01:00:00        90      NaN      NaN      NaN      NaN          90
# 1979-01-01 02:00:00       120      NaN      NaN      NaN      NaN          90
# 1979-01-01 03:00:00       160      NaN      NaN      NaN      NaN          90
# 1979-01-01 04:00:00       160      0.5      NaN      NaN      NaN          90
#
#                      weather_id weather_main
# dt_iso
# 1979-01-01 00:00:00         300      Drizzle
# 1979-01-01 01:00:00         600         Snow
# 1979-01-01 02:00:00         804       Clouds
# 1979-01-01 03:00:00         804       Clouds
# 1979-01-01 04:00:00         500         Rain

# %%
df_lr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 364512 entries, 1979-01-01 00:00:00 to 2020-07-31 23:00:00
# Data columns (total 13 columns):
# temp            364512 non-null float64
# feels_like      364512 non-null float64
# pressure        364512 non-null int64
# humidity        364512 non-null int64
# wind_speed      364512 non-null float64
# wind_deg        364512 non-null int64
# rain_1h         29698 non-null float64
# rain_3h         1594 non-null float64
# snow_1h         11440 non-null float64
# snow_3h         911 non-null float64
# clouds_all      364512 non-null int64
# weather_id      364512 non-null int64
# weather_main    364512 non-null object
# dtypes: float64(7), int64(5), object(1)
# memory usage: 38.9+ MB

# %% [markdown]
# We first get rid of the categorical datas.

# %%
df_lr = df_lr.drop(columns = ['weather_id', 'weather_main', 'wind_deg'])
df_lr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 364512 entries, 1979-01-01 00:00:00 to 2020-07-31 23:00:00
# Data columns (total 10 columns):
# temp          364512 non-null float64
# feels_like    364512 non-null float64
# pressure      364512 non-null int64
# humidity      364512 non-null int64
# wind_speed    364512 non-null float64
# rain_1h       29698 non-null float64
# rain_3h       1594 non-null float64
# snow_1h       11440 non-null float64
# snow_3h       911 non-null float64
# clouds_all    364512 non-null int64
# dtypes: float64(7), int64(3)
# memory usage: 30.6 MB

# %% [markdown]
# The rain and snow features contain a lot of missing values, which is normal since there are many days without precipitation. We replace those missing values with 0.

# %%
# iterate over the precipitation columns
for col in ['rain_1h', 'rain_3h', 'snow_1h', 'snow_3h']:
    df_lr[col] = df_lr[col].fillna(0)

# %%
df_lr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 364512 entries, 1979-01-01 00:00:00 to 2020-07-31 23:00:00
# Data columns (total 10 columns):
# temp          364512 non-null float64
# feels_like    364512 non-null float64
# pressure      364512 non-null int64
# humidity      364512 non-null int64
# wind_speed    364512 non-null float64
# rain_1h       364512 non-null float64
# rain_3h       364512 non-null float64
# snow_1h       364512 non-null float64
# snow_3h       364512 non-null float64
# clouds_all    364512 non-null int64
# dtypes: float64(7), int64(3)
# memory usage: 30.6 MB

# %% [markdown]
# We create a Dataframe containing daily datas, rather than hourly datas. We take average temperature, pressure, humiditity, wind_speed and cloudiness, and we add the values for precipitation. The 'rain_3h' and 'snow_3h' features thus become irrelevant.

# %%
df_lr=df_lr.drop(columns = ['rain_3h', 'snow_3h'])

# %%
df_lr_daily = pd.DataFrame()
df_lr_daily['temp'] = df_lr.temp.resample('D').mean()
df_lr_daily['feels_like'] = df_lr.feels_like.resample('D').mean()
df_lr_daily['pressure'] = df_lr.pressure.resample('D').mean()
df_lr_daily['humidity'] = df_lr.humidity.resample('D').mean()
df_lr_daily['wind_speed'] = df_lr.wind_speed.resample('D').mean()
df_lr_daily['rain_1h'] = df_lr.rain_1h.resample('D').sum()
df_lr_daily['snow_1h'] = df_lr.snow_1h.resample('D').sum()
df_lr_daily['clouds_all'] = df_lr.clouds_all.resample('D').mean()

# %%
df_lr_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15188 entries, 1979-01-01 to 2020-07-31
# Freq: D
# Data columns (total 8 columns):
# temp          15188 non-null float64
# feels_like    15188 non-null float64
# pressure      15188 non-null float64
# humidity      15188 non-null float64
# wind_speed    15188 non-null float64
# rain_1h       15188 non-null float64
# snow_1h       15188 non-null float64
# clouds_all    15188 non-null float64
# dtypes: float64(8)
# memory usage: 1.0 MB

# %%
df_lr_daily.head()
# Out:
#                   temp  feels_like     pressure   humidity  wind_speed  \
# dt_iso
# 1979-01-01  276.995417  270.425000  1013.083333  90.791667    7.129167
# 1979-01-02  273.907500  268.971667  1006.750000  91.708333    4.179167
# 1979-01-03  263.207500  254.094583  1012.041667  74.625000    8.350000
# 1979-01-04  262.007917  253.874583  1024.583333  67.375000    6.737500
# 1979-01-05  261.500000  252.537917  1029.916667  59.833333    7.795833
#
#             rain_1h  snow_1h  clouds_all
# dt_iso
# 1979-01-01    11.32     0.00   90.000000
# 1979-01-02     8.95     3.56   89.375000
# 1979-01-03     0.00     3.77   62.291667
# 1979-01-04     0.00     0.00   65.291667
# 1979-01-05     0.00     0.00   29.166667

# %% [markdown]
# We create, for each day, features encoding the datas 3 days prior.

# %%
#Adds a column of a given feature N days prior. 
def prior_n_day_feature(df, feature, N):
    rows = df.shape[0]
    prior_n_datas = [None]*N + [df[feature][i-N] for i in range(N, rows)]
    col_name = "{}_{}".format(feature, N)
    df[col_name] = prior_n_datas

# %%
#Loop over all features and N = 1,2,3
for feature in df_lr_daily.columns:
    for N in range(1, 4):
            prior_n_day_feature(df_lr_daily, feature, N)

# %%
pd.set_option('display.max_columns', 999)

# %%
df_lr_daily.head()
# Out:
#                   temp  feels_like     pressure   humidity  wind_speed  \
# dt_iso
# 1979-01-01  276.995417  270.425000  1013.083333  90.791667    7.129167
# 1979-01-02  273.907500  268.971667  1006.750000  91.708333    4.179167
# 1979-01-03  263.207500  254.094583  1012.041667  74.625000    8.350000
# 1979-01-04  262.007917  253.874583  1024.583333  67.375000    6.737500
# 1979-01-05  261.500000  252.537917  1029.916667  59.833333    7.795833
#
#             rain_1h  snow_1h  clouds_all      temp_1      temp_2      temp_3  \
# dt_iso
# 1979-01-01    11.32     0.00   90.000000         NaN         NaN         NaN
# 1979-01-02     8.95     3.56   89.375000  276.995417         NaN         NaN
# 1979-01-03     0.00     3.77   62.291667  273.907500  276.995417         NaN
# 1979-01-04     0.00     0.00   65.291667  263.207500  273.907500  276.995417
# 1979-01-05     0.00     0.00   29.166667  262.007917  263.207500  273.907500
#
#             feels_like_1  feels_like_2  feels_like_3   pressure_1  \
# dt_iso
# 1979-01-01           NaN           NaN           NaN          NaN
# 1979-01-02    270.425000           NaN           NaN  1013.083333
# 1979-01-03    268.971667    270.425000           NaN  1006.750000
# 1979-01-04    254.094583    268.971667    270.425000  1012.041667
# 1979-01-05    253.874583    254.094583    268.971667  1024.583333
#
#              pressure_2   pressure_3  humidity_1  humidity_2  humidity_3  \
# dt_iso
# 1979-01-01          NaN          NaN         NaN         NaN         NaN
# 1979-01-02          NaN          NaN   90.791667         NaN         NaN
# 1979-01-03  1013.083333          NaN   91.708333   90.791667         NaN
# 1979-01-04  1006.750000  1013.083333   74.625000   91.708333   90.791667
# 1979-01-05  1012.041667  1006.750000   67.375000   74.625000   91.708333
#
#             wind_speed_1  wind_speed_2  wind_speed_3  rain_1h_1  rain_1h_2  \
# dt_iso
# 1979-01-01           NaN           NaN           NaN        NaN        NaN
# 1979-01-02      7.129167           NaN           NaN      11.32        NaN
# 1979-01-03      4.179167      7.129167           NaN       8.95      11.32
# 1979-01-04      8.350000      4.179167      7.129167       0.00       8.95
# 1979-01-05      6.737500      8.350000      4.179167       0.00       0.00
#
#             rain_1h_3  snow_1h_1  snow_1h_2  snow_1h_3  clouds_all_1  \
# dt_iso
# 1979-01-01        NaN        NaN        NaN        NaN           NaN
# 1979-01-02        NaN       0.00        NaN        NaN     90.000000
# 1979-01-03        NaN       3.56       0.00        NaN     89.375000
# 1979-01-04      11.32       3.77       3.56       0.00     62.291667
# 1979-01-05       8.95       0.00       3.77       3.56     65.291667
#
#             clouds_all_2  clouds_all_3
# dt_iso
# 1979-01-01           NaN           NaN
# 1979-01-02           NaN           NaN
# 1979-01-03     90.000000           NaN
# 1979-01-04     89.375000        90.000
# 1979-01-05     62.291667        89.375

# %%
df_lr_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15188 entries, 1979-01-01 to 2020-07-31
# Freq: D
# Data columns (total 32 columns):
# temp            15188 non-null float64
# feels_like      15188 non-null float64
# pressure        15188 non-null float64
# humidity        15188 non-null float64
# wind_speed      15188 non-null float64
# rain_1h         15188 non-null float64
# snow_1h         15188 non-null float64
# clouds_all      15188 non-null float64
# temp_1          15187 non-null float64
# temp_2          15186 non-null float64
# temp_3          15185 non-null float64
# feels_like_1    15187 non-null float64
# feels_like_2    15186 non-null float64
# feels_like_3    15185 non-null float64
# pressure_1      15187 non-null float64
# pressure_2      15186 non-null float64
# pressure_3      15185 non-null float64
# humidity_1      15187 non-null float64
# humidity_2      15186 non-null float64
# humidity_3      15185 non-null float64
# wind_speed_1    15187 non-null float64
# wind_speed_2    15186 non-null float64
# wind_speed_3    15185 non-null float64
# rain_1h_1       15187 non-null float64
# rain_1h_2       15186 non-null float64
# rain_1h_3       15185 non-null float64
# snow_1h_1       15187 non-null float64
# snow_1h_2       15186 non-null float64
# snow_1h_3       15185 non-null float64
# clouds_all_1    15187 non-null float64
# clouds_all_2    15186 non-null float64
# clouds_all_3    15185 non-null float64
# dtypes: float64(32)
# memory usage: 4.4 MB

# %% [markdown]
# As we only want to predict 'temp' and we will only use datas from previous days, we drop the other features giving datas for the same day.

# %%
df_lr_daily = df_lr_daily.drop(columns = ['feels_like', 'pressure', 'humidity', 'wind_speed', 'rain_1h',
                              'snow_1h','clouds_all'])

# %%
df_lr_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15188 entries, 1979-01-01 to 2020-07-31
# Freq: D
# Data columns (total 25 columns):
# temp            15188 non-null float64
# temp_1          15187 non-null float64
# temp_2          15186 non-null float64
# temp_3          15185 non-null float64
# feels_like_1    15187 non-null float64
# feels_like_2    15186 non-null float64
# feels_like_3    15185 non-null float64
# pressure_1      15187 non-null float64
# pressure_2      15186 non-null float64
# pressure_3      15185 non-null float64
# humidity_1      15187 non-null float64
# humidity_2      15186 non-null float64
# humidity_3      15185 non-null float64
# wind_speed_1    15187 non-null float64
# wind_speed_2    15186 non-null float64
# wind_speed_3    15185 non-null float64
# rain_1h_1       15187 non-null float64
# rain_1h_2       15186 non-null float64
# rain_1h_3       15185 non-null float64
# snow_1h_1       15187 non-null float64
# snow_1h_2       15186 non-null float64
# snow_1h_3       15185 non-null float64
# clouds_all_1    15187 non-null float64
# clouds_all_2    15186 non-null float64
# clouds_all_3    15185 non-null float64
# dtypes: float64(25)
# memory usage: 3.6 MB

# %% [markdown]
# We want to deal with the missing datas. The new features all have missing values in the first 3 days, because we did not have the datas prior to that. So we remove the first three rows.

# %%
df_lr_daily = df_lr_daily.iloc[3:]

# %%
df_lr_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15185 entries, 1979-01-04 to 2020-07-31
# Freq: D
# Data columns (total 25 columns):
# temp            15185 non-null float64
# temp_1          15185 non-null float64
# temp_2          15185 non-null float64
# temp_3          15185 non-null float64
# feels_like_1    15185 non-null float64
# feels_like_2    15185 non-null float64
# feels_like_3    15185 non-null float64
# pressure_1      15185 non-null float64
# pressure_2      15185 non-null float64
# pressure_3      15185 non-null float64
# humidity_1      15185 non-null float64
# humidity_2      15185 non-null float64
# humidity_3      15185 non-null float64
# wind_speed_1    15185 non-null float64
# wind_speed_2    15185 non-null float64
# wind_speed_3    15185 non-null float64
# rain_1h_1       15185 non-null float64
# rain_1h_2       15185 non-null float64
# rain_1h_3       15185 non-null float64
# snow_1h_1       15185 non-null float64
# snow_1h_2       15185 non-null float64
# snow_1h_3       15185 non-null float64
# clouds_all_1    15185 non-null float64
# clouds_all_2    15185 non-null float64
# clouds_all_3    15185 non-null float64
# dtypes: float64(25)
# memory usage: 3.0 MB

# %% [markdown]
# ### Analysing the datas

# %% [markdown]
# We are now ready to analyse the datas in more depth.

# %%
df_lr_desc = df_lr_daily.describe().T
df_lr_desc.head(35)
# Out:
#                 count         mean        std         min          25%  \
# temp          15185.0   280.267413  11.738474  241.882083   271.714167
# temp_1        15185.0   280.265338  11.738705  241.882083   271.713333
# temp_2        15185.0   280.263928  11.738182  241.882083   271.713333
# temp_3        15185.0   280.262645  11.737475  241.882083   271.713333
# feels_like_1  15185.0   276.461313  13.830633  233.927083   266.054167
# feels_like_2  15185.0   276.459557  13.829890  233.927083   266.054167
# feels_like_3  15185.0   276.457819  13.828990  233.927083   266.054167
# pressure_1    15185.0  1014.964365   8.444787  973.916667  1009.708333
# pressure_2    15185.0  1014.965158   8.443450  973.916667  1009.708333
# pressure_3    15185.0  1014.966675   8.441041  973.916667  1009.708333
# humidity_1    15185.0    70.376759  12.620528   27.166667    62.208333
# humidity_2    15185.0    70.377568  12.621502   27.166667    62.208333
# humidity_3    15185.0    70.378641  12.622544   27.166667    62.208333
# wind_speed_1  15185.0     3.933432   1.623734    0.877083     2.723333
# wind_speed_2  15185.0     3.933472   1.623733    0.877083     2.723333
# wind_speed_3  15185.0     3.933690   1.623939    0.877083     2.723333
# rain_1h_1     15185.0     1.787582   4.862009    0.000000     0.000000
# rain_1h_2     15185.0     1.788139   4.862345    0.000000     0.000000
# rain_1h_3     15185.0     1.788805   4.862958    0.000000     0.000000
# snow_1h_1     15185.0     0.411192   1.960086    0.000000     0.000000
# snow_1h_2     15185.0     0.411426   1.960250    0.000000     0.000000
# snow_1h_3     15185.0     0.411426   1.960250    0.000000     0.000000
# clouds_all_1  15185.0    56.491101  26.113230    0.000000    36.041667
# clouds_all_2  15185.0    56.494166  26.114358    0.000000    36.041667
# clouds_all_3  15185.0    56.497015  26.115654    0.000000    36.041667
#
#                       50%          75%          max
# temp           281.030000   290.562500   302.750000
# temp_1         281.023333   290.556667   302.750000
# temp_2         281.021667   290.555000   302.750000
# temp_3         281.019167   290.554583   302.750000
# feels_like_1   276.603333   288.542083   304.980417
# feels_like_2   276.602500   288.541250   304.980417
# feels_like_3   276.601250   288.540833   304.980417
# pressure_1    1015.000000  1020.291667  1048.375000
# pressure_2    1015.000000  1020.291667  1048.375000
# pressure_3    1015.000000  1020.291667  1048.375000
# humidity_1      71.041667    79.333333   100.000000
# humidity_2      71.041667    79.333333   100.000000
# humidity_3      71.041667    79.333333   100.000000
# wind_speed_1     3.654167     4.850000    12.941667
# wind_speed_2     3.654167     4.850000    12.941667
# wind_speed_3     3.654167     4.850000    12.941667
# rain_1h_1        0.000000     1.020000    72.220000
# rain_1h_2        0.000000     1.020000    72.220000
# rain_1h_3        0.000000     1.020000    72.220000
# snow_1h_1        0.000000     0.000000    35.270000
# snow_1h_2        0.000000     0.000000    35.270000
# snow_1h_3        0.000000     0.000000    35.270000
# clouds_all_1    59.333333    79.208333   100.000000
# clouds_all_2    59.333333    79.208333   100.000000
# clouds_all_3    59.333333    79.208333   100.000000

# %% [markdown]
# We see that the precipitations datas are mostly made of zeros, creating some outliers. We leave them for now, as this can easily be explained.

# %% [markdown]
# We can now plot the different distributions for each feature.

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.temp_1.hist()
plt.title('Distribution of temp_1')
plt.xlabel('temp_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.feels_like_1.hist()
plt.title('Distribution of feels_like_1')
plt.xlabel('feels_like_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.pressure_1.hist()
plt.title('Distribution of pressure_1')
plt.xlabel('pressure_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.humidity_1.hist()
plt.title('Distribution of humidity_1')
plt.xlabel('humidity_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.wind_speed_1.hist()
plt.title('Distribution of wind_speed_1')
plt.xlabel('wind_speed_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.rain_1h_1.hist()
plt.title('Distribution of rain_1h_1')
plt.xlabel('rain_1h_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.snow_1h_1.hist()
plt.title('Distribution of snow_1h_1')
plt.xlabel('snow_1h_1')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [14, 8]
df_lr_daily.clouds_all_1.hist()
plt.title('Distribution of clouds_all_1')
plt.xlabel('clouds_all_1')
plt.show()

# %% [markdown]
# We now check the correllations between the features. We only consider the features of 1 day prior, since features containing the same datas will certainly be correlated.

# %%
df_lr_corr = df_lr_daily[['temp_1', 'feels_like_1', 'pressure_1', 'humidity_1', 'wind_speed_1', 'rain_1h_1', 
                   'snow_1h_1','clouds_all_1']].copy()
df_lr_corr = df_lr_corr.corr().abs().unstack().sort_values(kind='quicksort', ascending=False).reset_index()
df_lr_corr.rename(columns={"level_0": "Feature 1", "level_1": "Feature 2", 0:'Correlation Coefficient'}, inplace=True)
df_lr_corr.drop(df_lr_corr.iloc[1::2].index,inplace=True)
#Remove perfect correlation
df_lr_corr_nd = df_lr_corr.drop(df_lr_corr[(df_lr_corr['Correlation Coefficient']== 1.0)].index)
# Show high correlations
df_lr_corr_nd[(df_lr_corr_nd['Correlation Coefficient']>0.1)]
# Out:
#        Feature 1     Feature 2  Correlation Coefficient
# 8   feels_like_1        temp_1                 0.994586
# 10  clouds_all_1    humidity_1                 0.580065
# 12  clouds_all_1    pressure_1                 0.402557
# 14    pressure_1  wind_speed_1                 0.340277
# 16     rain_1h_1  clouds_all_1                 0.336577
# 18     rain_1h_1    humidity_1                 0.323726
# 20    pressure_1    humidity_1                 0.291217
# 22     rain_1h_1    pressure_1                 0.262515
# 24  feels_like_1  wind_speed_1                 0.249419
# 26        temp_1    pressure_1                 0.242280
# 28  clouds_all_1     snow_1h_1                 0.227342
# 30     snow_1h_1  feels_like_1                 0.216659
# 32    pressure_1  feels_like_1                 0.215141
# 34        temp_1     snow_1h_1                 0.211014
# 36  clouds_all_1  wind_speed_1                 0.207567
# 38     snow_1h_1    humidity_1                 0.198456
# 40     rain_1h_1        temp_1                 0.171935
# 42     rain_1h_1  feels_like_1                 0.171889
# 44        temp_1  wind_speed_1                 0.166841
# 46     snow_1h_1  wind_speed_1                 0.149400
# 48    pressure_1     snow_1h_1                 0.115472
# 50     rain_1h_1  wind_speed_1                 0.102060

# %% [markdown]
# We make a correlation heat map.

# %%
import seaborn as sns

def correlation_heatmap(df):
    correlations = df.corr()

    fig, ax = plt.subplots(figsize=(20,20))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f',
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
    plt.show();
    
correlation_heatmap(df_lr_daily)

# %% [markdown]
# Unsurprinsingly, we see a high correlation between 'temp' and 'feels_like'. We thus remove 'feel_like', as it is not providing new information in our prediction model. 'Humidity' and 'clouds_all', as well as 'pressure' and 'clouds_all' are also fairly corrolated, with above 0.3 correlation coefficient.

# %%
df_lr_daily = df_lr_daily.drop(columns = ['feels_like_1', 'feels_like_2', 'feels_like_3'])

# %% [markdown]
# We now look at the correlation between the different features and 'temp', the feature we want to predict.

# %%
df_lr_corr_temp = df_lr_daily.corr().abs()[['temp']].sort_values('temp')
df_lr_corr_temp.head(35)
# Out:
#                   temp
# humidity_1    0.035579
# pressure_2    0.043638
# pressure_3    0.065735
# humidity_2    0.092549
# humidity_3    0.102051
# pressure_1    0.102663
# rain_1h_2     0.105905
# rain_1h_3     0.113423
# rain_1h_1     0.125746
# clouds_all_1  0.147619
# clouds_all_3  0.197048
# clouds_all_2  0.206015
# wind_speed_3  0.234501
# snow_1h_1     0.236052
# snow_1h_3     0.238490
# snow_1h_2     0.253927
# wind_speed_2  0.263544
# wind_speed_1  0.265297
# temp_3        0.877751
# temp_2        0.897084
# temp_1        0.947140
# temp          1.000000

# %% [markdown]
# In our model, we only keep the features with the highest correlation, that is 'temp', 'wind_speed', 'snow_1h'.

# %%
df_lr_daily = df_lr_daily[['wind_speed_1', 'wind_speed_2',
              'wind_speed_3','snow_1h_1', 'snow_1h_2', 'snow_1h_3',
                'temp_1', 'temp_2', 'temp_3', 'temp']]
df_lr_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15185 entries, 1979-01-04 to 2020-07-31
# Freq: D
# Data columns (total 10 columns):
# wind_speed_1    15185 non-null float64
# wind_speed_2    15185 non-null float64
# wind_speed_3    15185 non-null float64
# snow_1h_1       15185 non-null float64
# snow_1h_2       15185 non-null float64
# snow_1h_3       15185 non-null float64
# temp_1          15185 non-null float64
# temp_2          15185 non-null float64
# temp_3          15185 non-null float64
# temp            15185 non-null float64
# dtypes: float64(10)
# memory usage: 1.3 MB

# %% [markdown]
# We plot the different correlations into a scatter plot.

# %%
# %matplotlib inline
features = ['wind_speed_1', 'wind_speed_2',
              'wind_speed_3','snow_1h_1', 'snow_1h_2', 'snow_1h_3',
                'temp_1', 'temp_2', 'temp_3']

plt.rcParams['figure.figsize'] = [10, 90]
fig, axes = plt.subplots(nrows=9, ncols=1, sharey=True)
arr = np.array(features)

for i in range(len(arr)):
    axes[i].scatter(df_lr_daily[arr[i]], df_lr_daily['temp'])
    axes[i].set(xlabel=arr[i], ylabel='temp')

plt.show()

# %% [markdown]
# We are now ready to perform a linear regression model on our data set, which we save into a csv file.

# %%
df_lr_daily.to_csv("weather_data_lin_reg.csv", header=True, index=True)
